# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def cardapio():
    for chave, valor in cardapio.items():
        print(f'{chave}: {valor}')
{'Sushi (8 peças)': 60.00, 'Sashimi (10 fatias)' : 70.00 , 'Temaki' : 25.00, 'Yakisoba (porção média)' : 40.00, 'Ramen' : 50.00, 'Gyoza (6 unidades)' : 35.00
            ,'Karaage' : 40.00, 'Tonkatsu' : 45.00, 'Udon' : 40.00, 'Onigiri (1 unidade)' : 20.00}
# Out:
# {'Sushi (8 peças)': 60.0,
#  'Sashimi (10 fatias)': 70.0,
#  'Temaki': 25.0,
#  'Yakisoba (porção média)': 40.0,
#  'Ramen': 50.0,
#  'Gyoza (6 unidades)': 35.0,
#  'Karaage': 40.0,
#  'Tonkatsu': 45.0,
#  'Udon': 40.0,
#  'Onigiri (1 unidade)': 20.0}

# %%
pedido = input('Digite os itens do seu pedido: ')
valor_pedido = 

print(f'Seu pedido de {pedido} custa {} ')
