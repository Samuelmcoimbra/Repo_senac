# %%
import pandas as pd

# %%
df = pd.read_csv('fute.csv', encoding= 'latin1')
df
# Out:
#       temporada        data   horario              fase         tipo_fase  \
# 0     2003,2004  2003-11-05  15:45:00    Fase De Grupos           Grupo B
# 1     2003,2004  2004-04-07  15:45:00  Quartas De Final  Quartas De Final
# 2     2003,2004  2003-09-17  15:45:00    Fase De Grupos           Grupo B
# 3     2003,2004  2004-03-10  15:45:00  Oitavas De Final  Oitavas De Final
# 4     2003,2004  2003-12-10  15:45:00    Fase De Grupos           Grupo B
# ...         ...         ...       ...               ...               ...
# 2567  2023,2024  2023-11-28  16:00:00    Fase De Grupos           Grupo E
# 2568  2023,2024  2023-10-25  13:45:00    Fase De Grupos           Grupo E
# 2569  2023,2024  2023-09-19  16:00:00    Fase De Grupos           Grupo E
# 2570  2023,2024  2023-10-25  16:00:00    Fase De Grupos           Grupo F
# 2571  2023,2024  2023-10-04  16:00:00    Fase De Grupos           Grupo F
#
#                           estadio            arbitro  publico  publico_max  \
# ...

# %%
df_2023 = df.loc[df['temporada'] == '2023,2024']
df_2023
# Out:
#       temporada        data   horario            fase tipo_fase  \
# 2492  2023,2024  2023-11-29  16:00:00  Fase De Grupos   Grupo C
# 2493  2023,2024  2023-11-08  16:00:00  Fase De Grupos   Grupo C
# 2494  2023,2024  2023-09-20  13:45:00  Fase De Grupos   Grupo C
# 2495  2023,2024  2023-11-08  16:00:00  Fase De Grupos   Grupo B
# 2496  2023,2024  2023-09-20  16:00:00  Fase De Grupos   Grupo B
# ...         ...         ...       ...             ...       ...
# 2567  2023,2024  2023-11-28  16:00:00  Fase De Grupos   Grupo E
# 2568  2023,2024  2023-10-25  13:45:00  Fase De Grupos   Grupo E
# 2569  2023,2024  2023-09-19  16:00:00  Fase De Grupos   Grupo E
# 2570  2023,2024  2023-10-25  16:00:00  Fase De Grupos   Grupo F
# 2571  2023,2024  2023-10-04  16:00:00  Fase De Grupos   Grupo F
#
#                           estadio             arbitro  publico  publico_max  \
# 2492           Santiago Bernab̩u  Fran̤ois Letexier    83186          NaN
# ...

# %%
df_time = df_2023.loc[df_2023['time_mandante'] == '2023,2024']
df_time

# %%
df_valor_ordenado = df_2023.sort_values(by='valor_equipe_titular_mandante', ascending=False)
df_valor_ordenado
# Out:
#       temporada        data   horario            fase tipo_fase  \
# 2498  2023,2024  2023-11-28  16:00:00  Fase De Grupos   Grupo G
# 2499  2023,2024  2023-09-19  16:00:00  Fase De Grupos   Grupo G
# 2500  2023,2024  2023-11-07  16:00:00  Fase De Grupos   Grupo G
# 2495  2023,2024  2023-11-08  16:00:00  Fase De Grupos   Grupo B
# 2496  2023,2024  2023-09-20  16:00:00  Fase De Grupos   Grupo B
# ...         ...         ...       ...             ...       ...
# 2524  2023,2024  2023-10-04  16:00:00  Fase De Grupos   Grupo G
# 2523  2023,2024  2023-11-07  16:00:00  Fase De Grupos   Grupo G
# 2502  2023,2024  2023-11-28  16:00:00  Fase De Grupos   Grupo G
# 2503  2023,2024  2023-10-25  16:00:00  Fase De Grupos   Grupo G
# 2501  2023,2024  2023-09-19  13:45:00  Fase De Grupos   Grupo G
#
#                estadio          arbitro  publico  publico_max  \
# 2498    Etihad Stadium     Glenn Nyberg    51402      55017.0
# 2499    Etihad Stadium   Jọo Pinheiro    50204      55017.0
# ...

# %%
df_vic_ordenado = df_2023.sort_values(by='valor_equipe_titular_visitante')
df_vic_ordenado
