# %%
import pandas as pd

# %%
df = pd.read_csv('imdb.csv', encoding= 'latin1')
df
# Out:
#               id                                              title  \
# 0      tt0073470                         Strip Nude for Your Killer
# 1      tt0072764                                    Carry on Behind
# 2      tt0131526                 So Young, So Lovely, So Vicious...
# 3      tt0073335                                           Mahogany
# 4      tt0073006                                           Foreplay
# ...          ...                                                ...
# 33595  tt0095428                                             Kansas
# 33596  tt0094980  The Decline of Western Civilization Part II: T...
# 33597  tt0093170                                 Man Behind the Sun
# 33598  tt0170783                                          Yesterday
# 33599  tt0096516                             Straight for the Heart
#
#                                        link  year duration rating_mpa  \
# 0      https://www.imdb.com/title/tt0073470  1975   1h 38m  Not Rated
# ...

# %%
df_ordenado_rating = df.sort_values(by='rating_imdb', ascending=False)
df_ordenado_rating
# Out:
#                id                                           title  \
# 11166  tt29630400                         Day by Day: The Dynasty
# 20986  tt10950526                                Love Goes Public
# 12225  tt14016126                                   Water Brother
# 14532  tt30247072  SEVENTEEN TOUR 'FOLLOW' to JAPAN: LIVE VIEWING
# 27302  tt31353888                        The Cowboy and the Queen
# ...           ...                                             ...
# 32901   tt0246239                                 A Smaller World
# 33022   tt8870898             Bolshoi Ballet: The Sleeping Beauty
# 33076  tt10159942           Diana Ross: Her Life, Love and Legacy
# 33299   tt9358506                                       Blond sex
# 33409  tt15119488                               CatVideoFest 2021
#
#                                         link  year duration rating_mpa  \
# 11166  https://www.imdb.com/title/tt29630400  2023    2h 9m        NaN
# ...

# %%
df_ordenado_budget = df.sort_values(by='budget', ascending=False)
df_ordenado_budget
# Out:
#                id                                  title  \
# 797    tt23630030                                 Harbin
# 16035   tt8116428  Along With the Gods: The Last 49 Days
# 1019    tt0091605                   The Name of the Rose
# 706     tt1606384                                 My Way
# 10351  tt20168564                               Alienoid
# ...           ...                                    ...
# 33591   tt0221278                         The Insatiable
# 33595   tt0095428                                 Kansas
# 33597   tt0093170                     Man Behind the Sun
# 33598   tt0170783                              Yesterday
# 33599   tt0096516                 Straight for the Heart
#
#                                         link  year duration rating_mpa  \
# 797    https://www.imdb.com/title/tt23630030  2024   1h 48m        NaN
# 16035   https://www.imdb.com/title/tt8116428  2018   2h 22m  Not Rated
# ...

# %%
df_ordenado_budget.head(10)
# Out:
#                id                                  title  \
# 797    tt23630030                                 Harbin
# 16035   tt8116428  Along With the Gods: The Last 49 Days
# 1019    tt0091605                   The Name of the Rose
# 706     tt1606384                                 My Way
# 10351  tt20168564                               Alienoid
# 17857  tt27688034                               The Moon
# 10541  tt14810692                  Escape from Mogadishu
# 27506   tt8290698                     The Spy Gone North
# 28838   tt6931414                       The Great Battle
# 9983    tt0118799                      Life Is Beautiful
#
#                                         link  year duration rating_mpa  \
# 797    https://www.imdb.com/title/tt23630030  2024   1h 48m        NaN
# 16035   https://www.imdb.com/title/tt8116428  2018   2h 22m  Not Rated
# 1019    https://www.imdb.com/title/tt0091605  1986   2h 10m          R
# ...

# %%
df_ordenado_rating.head(10)
# SEVENTEEN TOUR 'FOLLOW' to JAPAN: LIVE VIEWING, BTS World Tour 'Love Yourself: Speak Yourself'..., Laufey's A Night at the Symphony: Hollywood Bowl
# Attack on Titan the Movie: The Last Attack, Twiceland - 5
# São filmes ou live events de marcas conhecidas de fora do cinema. Se tirar o AoT todos os outros 4 são de grupos musicais e 3 dos 4 são grupos de kpop
# O filme Day by Day: The Dynasty é sobre outra marca conhecida de fora do cinema (futebol americano)
# 7 São documentários
# 4 são sobre música
# Out:
#                id                                              title  \
# 11166  tt29630400                            Day by Day: The Dynasty
# 20986  tt10950526                                   Love Goes Public
# 12225  tt14016126                                      Water Brother
# 14532  tt30247072     SEVENTEEN TOUR 'FOLLOW' to JAPAN: LIVE VIEWING
# 27302  tt31353888                           The Cowboy and the Queen
# 32406  tt11119936  BTS World Tour 'Love Yourself: Speak Yourself'...
# 11363   tt0126079                                   Steeper & Deeper
# 13615  tt34227779   Laufey's A Night at the Symphony: Hollywood Bowl
# 23739  tt33175825         Attack on Titan the Movie: The Last Attack
# 25542   tt9386922                                          Twiceland
#
#                                         link  year duration rating_mpa  \
# 11166  https://www.imdb.com/title/tt29630400  2023    2h 9m        NaN
# ...

# %%
df_ordenado_writ = df.sort_values(by='writer', )
df_ordenado_writ
# Out:
#               id                                              title  \
# 18582  tt0187445                                      Ranuva Veeran
# 32518  tt0057301                                  Mechte navstrechu
# 1422   tt0156864                                     Palum Pazhamum
# 17723  tt0156873                               Parthal Pasi Theerum
# 4233   tt0156874                                          Pasamalar
# ...          ...                                                ...
# 33510  tt0343107                   Tom Dowd & the Language of Music
# 33548  tt9810480                                      Made for More
# 33559  tt0259207                                          Backstage
# 33561  tt0265212                                      Grateful Dawg
# 33596  tt0094980  The Decline of Western Civilization Part II: T...
#
#                                        link  year duration rating_mpa  \
# 18582  https://www.imdb.com/title/tt0187445  1981   2h 32m  Not Rated
# ...
